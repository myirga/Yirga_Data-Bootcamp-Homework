# %%
# %matplotlib inline

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# File to Load
city_data_to_load = "data/city_data.csv"
ride_data_to_load = "data/ride_data.csv"

# %%
# Read the City and Ride Data
city_data = pd.read_csv(city_data_to_load)
ride_data = pd.read_csv(ride_data_to_load)

# %%
# Combine the data into a single dataset
pyber_df = pd.merge(ride_data, city_data, on="city", how="outer")

# %%
# Display the data table for preview
pyber_df.head()
# Out:
#                  city                 date   fare        ride_id  \
# 0  Lake Jonathanshire  2018-01-14 10:14:22  13.83  5739410935873
# 1  Lake Jonathanshire  2018-04-07 20:51:11  31.25  4441251834598
# 2  Lake Jonathanshire  2018-03-09 23:45:55  19.89  2389495660448
# 3  Lake Jonathanshire  2018-04-07 18:09:21  24.28  7796805191168
# 4  Lake Jonathanshire  2018-01-02 14:14:50  13.89   424254840012
#
#    driver_count   type
# 0             5  Urban
# 1             5  Urban
# 2             5  Urban
# 3             5  Urban
# 4             5  Urban

# %% [markdown]
# ## Bubble Plot of Ride Sharing Data

# %%
#Find Average Fare ($) Per City
#Find Total Number of Rides Per City
#Find Total Number of Drivers Per City
#Find City Type (Urban, Suburban, Rural)

# %%
pyber_cities = pd.DataFrame({"Average Fare per City":average_fare,
                 "Number of Rides": total_rides,
                 "Number of Drivers": total_drivers,
                 "City Type": city_type
})
pyber_cities.head(10)
# Out:
#                  Average Fare per City  Number of Rides  Number of Drivers  \
# Amandaburgh                  24.641667               18                 12
# Barajasview                  25.332273               22                 26
# Barronchester                36.422500               16                 11
# Bethanyland                  32.956111               18                 22
# Bradshawfurt                 40.064000               10                  7
# Brandonfort                  35.437368               19                 10
# Carriemouth                  28.314444               27                 52
# Christopherfurt              24.501852               27                 41
# Colemanland                  30.894545               22                 23
# Davidfurt                    31.995882               17                 23
#
#                 City Type
# Amandaburgh         Urban
# Barajasview         Urban
# Barronchester    Suburban
# Bethanyland      Suburban
# ...

# %%
#City Type (Urban, Suburban, Rural)
city_type = city_data_df.set_index('city')['type']
city_type.value_counts()
# Out:
# Urban       66
# Suburban    36
# Rural       18
# Name: type, dtype: int64

# %%
# Obtain the x and y coordinates for each of the three city types

# Build the scatter plots for each city types

# Incorporate the other graph properties

# Create a legend

# Incorporate a text label regarding circle size

# Save Figure

# %%
#Urban
urban = pyber_cities.loc[pyber_cities["City Type"]== "Urban"]

#suburban
suburban = pyber_cities.loc[pyber_cities["City Type"]== "Suburban"]

#rural
rural = pyber_cities.loc[pyber_cities["City Type"]== "Rural"]

# %%
#Urban
plt.scatter(urban["Number of Rides"], urban["Average Fare per City"], color = "gold", edgecolors="black", s = urban["Number of Drivers"]*20, label = "Urban", alpha = 0.75, linewidth = 1.5)

#Suburban
plt.scatter(suburban["Number of Rides"], suburban["Average Fare per City"], color = "lightskyblue", edgecolors ="black", s = suburban["Number of Drivers"]*15, label = "Suburban", alpha = 0.75, linewidth = 1.5)

#Rural
plt.scatter(rural["Number of Rides"], rural["Average Fare per City"], color = "lightcoral", edgecolors = "black", s = rural["Number of Drivers"]*15, label = "Rural", alpha = 0.75, linewidth = 1.5)

#Plot Bubble Plot

plt.title('Pyber Ride Sharing Data', fontsize=20)
plt.xlabel('Number of Rides(Per City)',fontsize=15)
plt.ylabel('Average Fare (USD)', fontsize=15)
plt.gcf().text( 1, 0.6,"Note:Bubble sizes are associated \nwith the number of drivers.", fontsize=12) 
plt.legend('title =City Types')
plt.grid()

# %%
# Save Figure
plt.savefig("../Images/RideSharingData.png")

# %%
# Show plot
plt.show()

# %% [markdown]
# ## Total Fares by City Type

# %%
#Sum of fares by city type.
city_fare_pie = pyber_df.groupby(["type"])["fare"].sum()
city_fare_pie
# Out:
# type
# Rural        4327.93
# Suburban    19356.33
# Urban       39854.38
# Name: fare, dtype: float64

# %%
# Build Pie Chart
labels = ["Rural","Suburban","Urban"]
explode = (0, 0, 0.1)
colors = ["gold", "lightskyblue", "lightcoral"]
plt.pie(fare_sum, explode=explode, labels=labels, colors=colors, autopct="%1.1f%%", shadow=True, startangle=150)
plt.title("% of Total Fares by City Type")
plt.axis("equal")
plt.legend(loc = "lower right")

# %%
# Save Figure
plt.savefig("../Images/TotalFaresbyCityType.png")

# %%
# Show Figure
plt.show()

# %% [markdown]
# ## Total Rides by City Type

# %%
#Total rides by city type.
city_rides_pie = pyber_df.groupby(["type"])["ride_id"].count()
city_rides_pie
# Out:
# type
# Rural        125
# Suburban     625
# Urban       1625
# Name: ride_id, dtype: int64

# %%
# Build Pie Chart
labels = ["Rural","Suburban","Urban"]
explode = (0, 0, 0.1)
colors = ["gold", "lightskyblue", "lightcoral"]
plt.pie(rides_count, explode=explode, labels=labels, colors=colors, autopct="%1.1f%%", shadow=True, startangle=150)
plt.title("% of Total Rides by City Type")
plt.axis("equal")
plt.legend(loc = "lower right")

# %%
# Save Figure
plt.savefig("../Images/TotalRidesbyCityType.png")

# %%
# Show Figure
plt.show()

# %% [markdown]
# ## Total Drivers by City Type

# %%
#Total driver count.
city_drivers_pie = pyber_df.groupby(["type"])["driver_count"].mean()
city_drivers_pie
# Out:
# type
# Rural        4.296000
# Suburban    13.712000
# Urban       36.678154
# Name: driver_count, dtype: float64

# %%
# Build Pie Chart
labels = ["Rural","Suburban","Urban"]
explode = (0, 0, 0.1)
colors = ["gold", "lightskyblue", "lightcoral"]
plt.pie(drivers_sum, explode=explode, labels=labels, colors=colors,autopct="%1.1f%%", shadow=True, startangle=150)
plt.title("% of Total Drivers by City Type")
plt.axis("equal")
plt.legend(loc = "lower right")

# %%
# Save Figure
plt.savefig("../Images/TotalDriversbyCityType.png")

# %%
# Show Figure
plt.show()
